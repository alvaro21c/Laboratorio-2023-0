# %%
import pandas as pd

# %%
df=pd.read_excel('pips.xlsx')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Crear una base de datos
datos={"autos":['city','ignis','800','venue','punto'],"marca":['Honda','Maruti','Hyundai','Hyundai','Fiat'],
       "costo":[90000,60000,100000,80000,95000],"year":[5,7,10,4,2]}

autos=pd.DataFrame(datos)
type(autos)
# Out:
# pandas.core.frame.DataFrame

# %%
autos
# Out:
#    autos    marca   costo  year
# 0   city    Honda   90000     5
# 1  ignis   Maruti   60000     7
# 2    800  Hyundai  100000    10
# 3  venue  Hyundai   80000     4
# 4  punto     Fiat   95000     2

# %%
autos.to_csv('prueba.csv') # exportar bbdd

# %%
df.head(6) # muestras las primeras cinco filas del dataframe, si quieres cambiar el total se coloca en ()
# Out:
#                      Gobierno regional  \
# 0                          LA LIBERTAD
# 1                             AREQUIPA
# 2                             AREQUIPA
# 3  PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                             AYACUCHO
# 5                             MOQUEGUA
#
#                                             Proyecto Registro de cierre  \
# 0         2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                    2088142-MAJES SIGUAS - II ETAPA                 NO
# 2  2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3  2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# 5  2046177-MEJORAMIENTO DE LA RED VIAL DEPARTAMEN...                 NO
#
#    Monto viable  Costo actualizado  % Var Costo  Devengo acum  Avanc financ %  \
# 0  1.847407e+09       3.148963e+09     0.704531  8.260285e+08       26.231764
# ...

# %%
df.tail(7) # cinco ultimas filas, si quiero otro numero se pone dentro del ()
# Out:
#      Gobierno regional                                           Proyecto  \
# 1935          AMAZONAS  2553415-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1936          AMAZONAS  2553405-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1937          AMAZONAS  2553402-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1938          AMAZONAS  2553393-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1939          AMAZONAS  2553377-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1940          AMAZONAS  2552901-ADQUISICION DE HEMOGLOBINOMETRO; EN EL...
# 1941              LIMA  2106392-CONSTRUCCIÓN Y EQUIPAMIENTO DEL HOSPIT...
#
#      Registro de cierre  Monto viable  Costo actualizado  % Var Costo  \
# 1935                 NO        2200.0             2200.0          0.0
# 1936                 NO        2200.0             2200.0          0.0
# 1937                 NO        2200.0             2200.0          0.0
# 1938                 NO        2200.0             2200.0          0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942 entries, 0 to 1941
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Gobierno regional   1940 non-null   object
#  1   Proyecto            1942 non-null   object
#  2   Registro de cierre  1942 non-null   object
#  3   Monto viable        1942 non-null   float64
#  4   Costo actualizado   1942 non-null   float64
#  5   % Var Costo         1941 non-null   float64
#  6   Devengo acum        1942 non-null   float64
#  7   Avanc financ %      1942 non-null   float64
#  8   Avanc físico %      1942 non-null   float64
#  9   Días de retraso     1942 non-null   int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 151.8+ KB

# %%
df.shape # dimensiones del dataframe
# Out:
# (1942, 10)

# %%
df.columns
# Out:
# Index(['Gobierno regional', 'Proyecto', 'Registro de cierre', 'Monto viable',
#        'Costo actualizado', '% Var Costo', 'Devengo acum', 'Avanc financ %',
#        'Avanc físico %', 'Días de retraso'],
#       dtype='object')

# %%
#contar valores de una columna
df['Registro de cierre'].value_counts() # como yo realizo un recuento de una variable en especifico.
# Out:
# NO    1806
# SI     136
# Name: Registro de cierre, dtype: int64

# %%
# Extraer datos
# .loc
df.loc[0:10,['Gobierno regional','Registro de cierre','Proyecto']] #para sacar dos o mas columnas colocarlas dentro de un corchete
# si yo pongo de la fila 0 a 10 efectivamente me muestra hasta la fila 10
# Out:
#                       Gobierno regional Registro de cierre  \
# 0                           LA LIBERTAD                 NO
# 1                              AREQUIPA                 NO
# 2                              AREQUIPA                 NO
# 3   PROVINCIA CONSTITUCIONAL DEL CALLAO                 NO
# 4                              AYACUCHO                 SI
# 5                              MOQUEGUA                 NO
# 6                              AREQUIPA                 NO
# 7                                 CUSCO                 NO
# 8                                  PUNO                 NO
# 9                               UCAYALI                 NO
# 10                                CUSCO                 SI
#
#                                              Proyecto
# 0          2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA
# 1                     2088142-MAJES SIGUAS - II ETAPA
# 2   2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...
# ...

# %%
# .iloc
df.iloc[0:10,'Proyecto'] #esto sale error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:769, in _LocationIndexer._validate_tuple_indexer(self, key)
#     768 try:
# --> 769     self._validate_key(k, i)
#     770 except ValueError as err:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1378, in _iLocIndexer._validate_key(self, key, axis)
#    1377 else:
# -> 1378     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 # .iloc
# ...

# %%
df.iloc[0:10,0:4] # .iloc solo trabaja con indices y .iloc me permite sacar mas de dos columnas
df.iloc[0:10,1:3] 

# aqui si pongo de la fila 0 a la 10 solo me muestra hasta la fila 9
# Out:
#                                             Proyecto Registro de cierre
# 0         2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                    2088142-MAJES SIGUAS - II ETAPA                 NO
# 2  2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3  2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# 5  2046177-MEJORAMIENTO DE LA RED VIAL DEPARTAMEN...                 NO
# 6  2078076-CONSTRUCCION DE VIA TRONCAL INTERCONEC...                 NO
# 7  2192979-MEJORAMIENTO INTEGRAL DE LA VIA EXPRES...                 NO
# 8  2271673-FORTALECIMIENTO DE LA CAPACIDAD RESOLU...                 NO
# 9  2260211-FORTALECIMIENTO DE LOS SERVICIOS DE SA...                 NO

# %%
df.loc[:,['Gobierno regional','Registro de cierre']].value_counts() # me permite un recuento agrupado por variables
# Out:
# Gobierno regional                    Registro de cierre
# LIMA                                 NO                    202
# AYACUCHO                             NO                    117
# AREQUIPA                             NO                    107
# APURIMAC                             NO                     97
# HUANCAVELICA                         NO                     94
# AMAZONAS                             NO                     92
# CUSCO                                NO                     87
# CAJAMARCA                            NO                     86
# SAN MARTIN                           NO                     83
# HUANUCO                              NO                     81
# JUNIN                                NO                     76
# LORETO                               NO                     76
# UCAYALI                              NO                     69
# PIURA                                NO                     65
# ...

# %%
# Cambiar la columna del indice
df1=pd.read_csv('titanic_train.csv')
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=df1.set_index('PassengerId')
df1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Crear filtro
x=df1['Sex']=='male' # x es el filtro o la condicion

df1[x] # me muestra los pasajeros solo varones
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
# ...               ...     ...                             ...   ...   ...
# 884                 0       2   Banfield, Mr. Frederick James  male  28.0
# 885                 0       3          Sutehall, Mr. Henry Jr  male  25.0
# 887                 0       2           Montvila, Rev. Juozas  male  27.0
# 890                 1       1           Behr, Mr. Karl Howell  male  26.0
# 891                 0       3             Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
y=df['Registro de cierre']=='SI'
df[y]
# Out:
#      Gobierno regional                                           Proyecto  \
# 4             AYACUCHO  2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...
# 10               CUSCO  2164798-MEJORAMIENTO DE LA TRANSITABILIDAD PEA...
# 29               PIURA                                            #ERROR!
# 35               CUSCO  2230327-MEJORAMIENTO DE LA CARRETERA HUANCARAN...
# 44              LORETO  2056395-MEJORAMIENTO DE LOS SERVICIOS DE SALUD...
# ...                ...                                                ...
# 1883         CAJAMARCA  2465378-REMODELACION DE LOSA DEPORTIVA; EN EL(...
# 1886        SAN MARTIN                                            #ERROR!
# 1907            LORETO  2493461-RENOVACION DE VEREDA; EN EL(LA) COMUNI...
# 1910               ICA  2520247-ADQUISICION DE CONGELADORA VERTICAL; E...
# 1931            LORETO  2525479-ADQUISICION DE TERRENO; EN EL(LA) IE 2...
#
#      Registro de cierre  Monto viable  Costo actualizado  % Var Costo  \
# ...

# %%
df1[-x]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# ...               ...     ...
# 881                 1       2
# 883                 0       3
# 886                 0       3
# 888                 1       1
# 889                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
df[-y]
# Out:
#                         Gobierno regional  \
# 0                             LA LIBERTAD
# 1                                AREQUIPA
# 2                                AREQUIPA
# 3     PROVINCIA CONSTITUCIONAL DEL CALLAO
# 5                                MOQUEGUA
# ...                                   ...
# 1937                             AMAZONAS
# 1938                             AMAZONAS
# 1939                             AMAZONAS
# 1940                             AMAZONAS
# 1941                                 LIMA
#
#                                                Proyecto Registro de cierre  \
# 0            2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                       2088142-MAJES SIGUAS - II ETAPA                 NO
# 2     2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3     2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 5     2046177-MEJORAMIENTO DE LA RED VIAL DEPARTAMEN...                 NO
# ...

# %%
# filtrado segun informacion y columna
x=autos['autos'].isin(['800','city']) # dentro de la dataframe autos, elijo la variable autos y seleccionos los tipos de autos
                                      #800 y city

autos.loc[x]
# Out:
#   autos    marca   costo  year
# 0  city    Honda   90000     5
# 2   800  Hyundai  100000    10

# %%
# Variables na
#x = df1['Sex'].notna() #muestra los que no son na
x = df1['Cabin'].isna() # muestra los na
df1.loc[x]
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
# cambiar el nombre de las columnas
df.rename(columns={'Gobierno regional':'GORE','Monto viable':'Monto inicial'},inplace=True)
df
# Out:
#                                      GORE  \
# 0                             LA LIBERTAD
# 1                                AREQUIPA
# 2                                AREQUIPA
# 3     PROVINCIA CONSTITUCIONAL DEL CALLAO
# 4                                AYACUCHO
# ...                                   ...
# 1937                             AMAZONAS
# 1938                             AMAZONAS
# 1939                             AMAZONAS
# 1940                             AMAZONAS
# 1941                                 LIMA
#
#                                                Proyecto Registro de cierre  \
# 0            2077997-PROYECTO CHAVIMOCHIC TERCERA ETAPA                 NO
# 1                       2088142-MAJES SIGUAS - II ETAPA                 NO
# 2     2233862-CONSTRUCCION DE LA VIA REGIONAL AREQUI...                 NO
# 3     2055912-MEJORAMIENTO DE LA AV. NESTOR GAMBETTA...                 NO
# 4     2165166-MEJORAMIENTO DE LA CAPACIDAD RESOLUTIV...                 SI
# ...

# %%
# Reemplazar valores dentro de una columna

autos
# Out:
#    autos    marca   costo  year
# 0   city    Honda   90000     5
# 1  ignis   Maruti   60000     7
# 2    800  Hyundai  100000    10
# 3  venue  Hyundai   80000     4
# 4  punto     Fiat   95000     2

# %%
autos['costo'] = autos['costo'].replace({60000:600000})
autos
# Out:
#    autos    marca   costo  year
# 0   city    Honda  900000     5
# 1  ignis   Maruti  600000     7
# 2    800  Hyundai  100000    10
# 3  venue  Hyundai   80000     4
# 4  punto     Fiat   95000     2

# %%
gas=['diesel','gasolina','gnv','glp','diesel']
autos['Tipo_combustible']=gas
autos
# Out:
#    autos    marca   costo  year Tipo_combustible
# 0   city    Honda  900000     5           diesel
# 1  ignis   Maruti  600000     7         gasolina
# 2    800  Hyundai  100000    10              gnv
# 3  venue  Hyundai   80000     4              glp
# 4  punto     Fiat   95000     2           diesel

# %%
autos.drop('Tipo_combustible',axis=1,inplace=True)
autos
# Out:
#    autos    marca   costo  year
# 0   city    Honda  900000     5
# 1  ignis   Maruti  600000     7
# 2    800  Hyundai  100000    10
# 3  venue  Hyundai   80000     4
# 4  punto     Fiat   95000     2
